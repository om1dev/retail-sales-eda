# %%
# In the superstore dataset, find out which columns need to be fixed for containing outliers. Use boxplots to visualize the outliers and plot labelled boxplots to identify the specific outliers in those columns. (using seaborn or plotly -> matplotlib) to find out columns containing outliers

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('../data/Sample.csv', encoding='latin1')
